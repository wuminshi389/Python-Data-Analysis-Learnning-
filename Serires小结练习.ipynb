# %%
'''创建一个包含10名学生数学成绩的Series，成绩范围在50-100之间。
计算平均分、最高分、最低分，并找出高于平均分的学生人数。'''
import pandas as pd
import numpy as np
import random
np.random.seed(42)
# 生成10个学生的数学成绩
scores = pd.Series([random.randint(50, 100) for _ in range(10)])
print('平均分：', scores.mean())
print('最高分：', scores.max())
print('最低分：', scores.min())
print('高于平均分的学生人数：', (scores > scores.mean()).sum())
# Out:
# 平均分： 72.7
# 最高分： 95
# 最低分： 53
# 高于平均分的学生人数： 5

# %%
# 给定某城市一周每天的最高温度Series，完成以下任务：
# 找出温度超过30度的天数
# 计算平均温度
# 将温度从高到低排序
# 找出温度变化最大的两天
temperatures = pd.Series([28, 31, 29, 32, 30, 27, 33], index=['周一', '周二', '周三', '周四', '周五', '周六', '周日'])
print(temperatures>30)
print(temperatures[temperatures>30])
print(temperatures.mean())  
print(temperatures.sort_values(ascending=False))
print(temperatures.diff().abs().max())
print(temperatures.diff().abs().sort_values(ascending=False).index[0:2])
# Out:
# 周一    False
# 周二     True
# 周三    False
# 周四     True
# 周五    False
# 周六    False
# 周日     True
# dtype: bool
# 周二    31
# 周四    32
# 周日    33
# dtype: int64
# 30.0
# 周日    33
# 周四    32
# 周二    31
# 周五    30
# 周三    29
# 周一    28
# 周六    27
# dtype: int64
# 6.0
# Index(['周日', '周二'], dtype='object')

# %%
# 给定某股票连续10个交易日的收盘价Series：
# 计算每日收益率（当日收盘价/前日收盘价 - 1）
# 找出收益率最高和最低的日期
# 计算波动率（收益率的标准差）

prices = pd.Series([102.3, 103.5, 105.1, 104.8, 106.2, 107.0, 106.5, 108.1, 109.3, 110.2], index=pd.date_range('2023-01-01', periods=10))
#计算每日收益率
daily_returns = prices.pct_change()
print(daily_returns)
# 找出收益率最高和最低的日期
print(daily_returns.idxmax())
print(daily_returns.idxmin())
# 计算波动率（收益率的标准差）
print(daily_returns.std())
print(daily_returns.var())
# Out:
# 0    10
# 1    11
# 2    12
# 3    13
# 4    14
# 5    15
# 6    16
# 7    17
# 8    18
# 9    19
# dtype: int64
# 0         NaN
# 1    0.100000
# 2    0.090909
# 3    0.083333
# 4    0.076923
# 5    0.071429
# 6    0.066667
# 7    0.062500
# 8    0.058824
# 9    0.055556
# dtype: float64
# 1    0.100000
# 2    0.090909
# 3    0.083333
# 4    0.076923
# 5    0.071429
# 6    0.066667
# 7    0.062500
# 8    0.058824
# 9    0.055556
# dtype: float64
